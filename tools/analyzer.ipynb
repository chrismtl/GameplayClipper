# %%
import pandas as pd

# %%
df = pd.read_csv("../data/out/detects/complete.csv")

# %%
df
# Out:
#    game        event  timestamp  confidence         video
# 0   bf2         menu      75.00    0.996812  complete.mp4
# 1   bf2           ag      80.00    0.999995  complete.mp4
# 2   bf2      loadout      94.00    0.882609  complete.mp4
# 3   bf2  spawn_troop      94.10    0.915503  complete.mp4
# 4   bf2     kill_brc     164.20    0.996173  complete.mp4
# 5   bf2     kill_sgt     165.40    0.990015  complete.mp4
# 6   bf2     kill_brc     169.80    0.995937  complete.mp4
# 7   bf2     kill_sgt     169.24    0.993528  complete.mp4
# 8   bf2        death     173.27    0.946100  complete.mp4
# 9   bf2      loadout     175.00    0.817436  complete.mp4
# 10  bf2  spawn_troop     175.21    0.901811  complete.mp4
# 11  bf2     kill_sgt     220.11    0.993145  complete.mp4
# 12  bf2        death     258.30    0.924569  complete.mp4
# 13  bf2      loadout     258.20    0.876073  complete.mp4
# 14  bf2  spawn_troop     259.29    0.960655  complete.mp4
# ...
