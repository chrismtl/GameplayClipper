# %%
import pandas as pd

# %%
df = pd.read_csv("../data/out/dataframes/complete.csv")

# %%
df
# Out:
#    game        event    timestamp  confidence         video
# 0   bf2         menu  00:01:15:00    0.996812  complete.mp4
# 1   bf2           ag  00:01:20:00    0.999995  complete.mp4
# 2   bf2      loadout  00:01:34:00    0.882609  complete.mp4
# 3   bf2  spawn_troop  00:02:06:18    0.995342  complete.mp4
# 4   bf2     kill_brc  00:02:44:20    0.996173  complete.mp4
# 5   bf2     kill_sgt  00:02:45:04    0.990015  complete.mp4
# 6   bf2     kill_brc  00:02:49:08    0.995937  complete.mp4
# 7   bf2     kill_sgt  00:02:49:24    0.993528  complete.mp4
# 8   bf2        death  00:02:53:27    0.946100  complete.mp4
# 9   bf2      loadout  00:02:55:00    0.817436  complete.mp4
# 10  bf2  spawn_troop  00:03:02:26    0.991495  complete.mp4
# 11  bf2     kill_sgt  00:03:40:11    0.993145  complete.mp4
# 12  bf2        death  00:04:18:03    0.924569  complete.mp4
# 13  bf2      loadout  00:04:18:20    0.876073  complete.mp4
# 14  bf2  spawn_troop  00:04:32:21    0.990809  complete.mp4
# ...
